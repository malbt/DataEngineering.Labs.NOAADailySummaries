# %%
from glob import glob
import pandas as pd
import os
import json
import json_helper

# %%
daily_summaries = json_helper.json_helper('/Users/mtessema/DataEngineering.Labs.NOAADailySummaries/data/daily_summaries/')

# %%
#df_daily_summaries
daily_summaries
# Out:
#                      date datatype            station attributes  value  \
# 0     2018-01-27T00:00:00     SNOW  GHCND:US1DENC0031       ,,N,      0
# 1     2018-01-27T00:00:00     PRCP  GHCND:US1DENC0032       ,,N,      0
# 2     2018-01-27T00:00:00     PRCP  GHCND:US1DENC0033       ,,N,      0
# 3     2018-01-27T00:00:00     SNOW  GHCND:US1DENC0033       ,,N,      0
# 4     2018-01-27T00:00:00     PRCP  GHCND:US1DENC0035       ,,N,      0
# ...                   ...      ...                ...        ...    ...
# 1164  2018-01-27T00:00:00     PRCP  GHCND:US1DENC0013       ,,N,      0
# 1165  2018-01-27T00:00:00     SNOW  GHCND:US1DENC0013       ,,N,      0
# 1166  2018-01-27T00:00:00     PRCP  GHCND:US1DENC0028       ,,N,      0
# 1167  2018-01-27T00:00:00     SNOW  GHCND:US1DENC0028       ,,N,      0
# 1168  2018-01-27T00:00:00     PRCP  GHCND:US1DENC0031       ,,N,      0
#
#                                          source
# 0     daily_summaries_FIPS10003_jan_2018_1.json
# 1     daily_summaries_FIPS10003_jan_2018_1.json
# 2     daily_summaries_FIPS10003_jan_2018_1.json
# 3     daily_summaries_FIPS10003_jan_2018_1.json
# 4     daily_summaries_FIPS10003_jan_2018_1.json
# ...                                         ...
# 1164  daily_summaries_FIPS10003_jan_2018_0.json
# 1165  daily_summaries_FIPS10003_jan_2018_0.json
# 1166  daily_summaries_FIPS10003_jan_2018_0.json
# 1167  daily_summaries_FIPS10003_jan_2018_0.json
# 1168  daily_summaries_FIPS10003_jan_2018_0.json
#
# [1169 rows x 6 columns]

# %%
df_daily_summaries = pd.DataFrame(daily_summaries)
df_daily_summaries
# Out:
#                      date datatype            station attributes  value  \
# 0     2018-01-27T00:00:00     SNOW  GHCND:US1DENC0031       ,,N,      0
# 1     2018-01-27T00:00:00     PRCP  GHCND:US1DENC0032       ,,N,      0
# 2     2018-01-27T00:00:00     PRCP  GHCND:US1DENC0033       ,,N,      0
# 3     2018-01-27T00:00:00     SNOW  GHCND:US1DENC0033       ,,N,      0
# 4     2018-01-27T00:00:00     PRCP  GHCND:US1DENC0035       ,,N,      0
# ...                   ...      ...                ...        ...    ...
# 1164  2018-01-27T00:00:00     PRCP  GHCND:US1DENC0013       ,,N,      0
# 1165  2018-01-27T00:00:00     SNOW  GHCND:US1DENC0013       ,,N,      0
# 1166  2018-01-27T00:00:00     PRCP  GHCND:US1DENC0028       ,,N,      0
# 1167  2018-01-27T00:00:00     SNOW  GHCND:US1DENC0028       ,,N,      0
# 1168  2018-01-27T00:00:00     PRCP  GHCND:US1DENC0031       ,,N,      0
#
#                                          source
# 0     daily_summaries_FIPS10003_jan_2018_1.json
# 1     daily_summaries_FIPS10003_jan_2018_1.json
# 2     daily_summaries_FIPS10003_jan_2018_1.json
# 3     daily_summaries_FIPS10003_jan_2018_1.json
# 4     daily_summaries_FIPS10003_jan_2018_1.json
# ...                                         ...
# 1164  daily_summaries_FIPS10003_jan_2018_0.json
# 1165  daily_summaries_FIPS10003_jan_2018_0.json
# 1166  daily_summaries_FIPS10003_jan_2018_0.json
# 1167  daily_summaries_FIPS10003_jan_2018_0.json
# 1168  daily_summaries_FIPS10003_jan_2018_0.json
#
# [1169 rows x 6 columns]

# %% [markdown]
# How many stations are there in total for FIPS10003

# %%
df_daily_summaries.station.nunique(dropna = True)
# Out:
# 17

# %% [markdown]
# Create a DataFrame called temps_max that only contains the entries from df_daily_summaries where the datatype column is equal to TMAX. This DataFrame should only retain the date column and the value column.

# %%
df_temps_max = df_daily_summaries[df_daily_summaries['datatype'].str.contains('TMAX')]
temps_max = df_temps_max.filter(['date', 'value'])

# %%
temps_max
# Out:
#                      date  value
# 17    2018-01-27T00:00:00    150
# 46    2018-01-28T00:00:00    133
# 88    2018-01-29T00:00:00     78
# 124   2018-01-30T00:00:00     39
# 163   2018-01-31T00:00:00      6
# 204   2018-01-01T00:00:00    -60
# 244   2018-01-02T00:00:00    -38
# 286   2018-01-03T00:00:00     -5
# 334   2018-01-04T00:00:00    -21
# 374   2018-01-05T00:00:00    -82
# 406   2018-01-06T00:00:00    -88
# 442   2018-01-07T00:00:00    -71
# 478   2018-01-08T00:00:00      6
# 505   2018-01-09T00:00:00     78
# 542   2018-01-10T00:00:00     56
# 580   2018-01-11T00:00:00    133
# 614   2018-01-12T00:00:00    167
# 655   2018-01-13T00:00:00    139
# 692   2018-01-14T00:00:00    -32
# 734   2018-01-15T00:00:00      0
# 777   2018-01-16T00:00:00     56
# 823   2018-01-17T00:00:00     22
# 862   2018-01-18T00:00:00     22
# 900   2018-01-19T00:00:00     83
# 937   2018-01-20T00:00:00    139
# 977   2018-01-21T00:00:00    117
# 1008  2018-01-22T00:00:00    156
# 1041  2018-01-23T00:00:00    172
# 1077  2018-01-24T00:00:00     72
# 1113  2018-01-25T00:00:00     28
# 1150  2018-01-26T00:00:00     39

# %% [markdown]
# How many entries are there in the temps_max DataFrame? What are the mean, min, and max values?

# %%
temps_max.describe()
# Out:
#             value
# count   31.000000
# mean    48.193548
# std     77.768640
# min    -88.000000
# 25%     -2.500000
# 50%     39.000000
# 75%    125.000000
# max    172.000000

# %% [markdown]
# Let's graph this DataFrame so we can get a visual representation for this information.

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x = temps_max['date'].str[8:10]
y = temps_max['value'] / 10

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, y)
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Max Temperatues Jan 2018')
# Out:
# [Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 0, 'day of month'),
#  Text(0.5, 1.0, 'Max Temperatues Jan 2018')]

# %% [markdown]
# Create a DataFrame called temps_min that only contains the entries from df_daily_summaries where the datatype column is equal to TMIN. This DataFrame should only retain the date column and the value column.

# %%
df_temps_min = df_daily_summaries[df_daily_summaries['datatype'].str.contains('TMIN')]
temps_min = df_temps_min.filter(['date', 'value'])

# %%
temps_min
# Out:
#                      date  value
# 18    2018-01-27T00:00:00    -49
# 47    2018-01-28T00:00:00     72
# 89    2018-01-29T00:00:00     33
# 125   2018-01-30T00:00:00    -55
# 164   2018-01-31T00:00:00    -93
# 205   2018-01-01T00:00:00   -149
# 245   2018-01-02T00:00:00   -116
# 287   2018-01-03T00:00:00   -132
# 335   2018-01-04T00:00:00    -93
# 375   2018-01-05T00:00:00   -121
# 407   2018-01-06T00:00:00   -138
# 443   2018-01-07T00:00:00   -166
# 479   2018-01-08T00:00:00   -105
# 506   2018-01-09T00:00:00    -60
# 543   2018-01-10T00:00:00    -49
# 581   2018-01-11T00:00:00     33
# 615   2018-01-12T00:00:00     83
# 656   2018-01-13T00:00:00    -71
# 693   2018-01-14T00:00:00   -105
# 735   2018-01-15T00:00:00    -88
# 778   2018-01-16T00:00:00    -16
# 824   2018-01-17T00:00:00    -77
# 863   2018-01-18T00:00:00    -99
# 901   2018-01-19T00:00:00    -66
# 938   2018-01-20T00:00:00    -38
# 978   2018-01-21T00:00:00    -32
# 1009  2018-01-22T00:00:00     39
# 1042  2018-01-23T00:00:00     44
# 1078  2018-01-24T00:00:00      6
# 1114  2018-01-25T00:00:00    -38
# 1151  2018-01-26T00:00:00    -66

# %% [markdown]
# How many entries are there in the temps_min DataFrame? What are the mean, min, and max values?

# %%
temps_min.describe()
# Out:
#             value
# count   31.000000
# mean   -55.225806
# std     65.749378
# min   -166.000000
# 25%   -102.000000
# 50%    -66.000000
# 75%    -24.000000
# max     83.000000

# %% [markdown]
# Graph the temps_min DataFrame

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
x = temps_min['date'].str[8:10]
y = temps_min['value'] / 10

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, y)
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Min Temperatues Jan 2018')
# Out:
# [Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 0, 'day of month'),
#  Text(0.5, 1.0, 'Min Temperatues Jan 2018')]

# %% [markdown]
# We can also plot both of these lines in the same graph.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, temps_max['value'] / 10, color='red')
ax.plot(x, temps_min['value'] / 10, color='blue')
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Min & Max Temperatues Jan 2018')
# Out:
# [Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 0, 'day of month'),
#  Text(0.5, 1.0, 'Min & Max Temperatues Jan 2018')]
